# %%
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import select
import time
import re
import os

def start_server(error_rate, num_pages, fanout, level_policy, port):
    cmd = f"./bin/server -e {error_rate} -n {num_pages} -f {fanout} -l {level_policy} -p {port}"
    server_process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    return server_process

def stop_server(server_process):
    server_process.terminate()

# %%
def wait_for_server_ready(server_process):
    start_time = time.time()
    timeout = 30  # Timeout in seconds

    while True:
        ready, _, _ = select.select([server_process.stdout], [], [], timeout)
        if ready:
            output_line = server_process.stdout.readline().decode()
            print(output_line, end="")
            if "New client connected" in output_line:
                break
        elif time.time() - start_time > timeout:
            raise TimeoutError("Server did not print 'New client connected' within the timeout period.")

def run_experiment(port, workload_path):
    client_cmd = f'./bin/client -p {port}'
    
    # Start the client process
    client_process = subprocess.Popen(client_cmd.split(), stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    
    # Wait for the server to print "New client connected"
    try:
        wait_for_server_ready(server_process)
    except TimeoutError as e:
        print(e)
        client_process.terminate()
        return None

    # Run the benchmark command
    benchmark_cmd = f'b {workload_path}\n'
    client_process.stdin.write(benchmark_cmd.encode())
    client_process.stdin.flush()

    time_taken = None
    while True:
        print("looping")
        # Wait for output from the server process
        ready, _, _ = select.select([server_process.stdout], [], [], 30)  # 1 second timeout
        if ready:
            output_line = server_process.stdout.readline().decode()
            print(output_line, end="")
            match = re.search(r'(\d+) microseconds', output_line)
            if match:
                time_taken = int(match.group(1))
                break

    client_process.terminate()
    return time_taken

# %%
params = {
    'error_rate': [0.01, 0.05],
    'num_pages': [256, 512, 1024],
    'fanout': [2, 5, 10],
    'level_policy': ['LAZY_LEVELED', 'LEVELED', 'TIERED'],
    'port': 1249
}

results = []

for error_rate, num_pages, fanout, level_policy in itertools.product(params['error_rate'], params['num_pages'], params['fanout'], params['level_policy']):
    server_process = start_server(error_rate, num_pages, fanout, level_policy, params['port'])
    time_taken = run_experiment(params['port'], 'workload.txt')
    stop_server(server_process)

    result = {
        'error_rate': error_rate,
        'num_pages': num_pages,
        'fanout': fanout,
        'level_policy': level_policy,
        'time_taken': time_taken
    }
    results.append(result)

results_df = pd.DataFrame(results)
# Out:
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 181743 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 176230 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 194845 microseconds (0 minutes, 0.19 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 180092 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 164570 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 217391 microseconds (0 minutes, 0.22 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 213615 microseconds (0 minutes, 0.21 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 199795 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 179534 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 162339 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 178856 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 184211 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 178531 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 157629 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 195337 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 174042 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 196545 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 194855 microseconds (0 minutes, 0.19 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 174550 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 179084 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 178211 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 182806 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 171453 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 162971 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 157294 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 164786 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 149609 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 161334 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 149669 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 169260 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 147755 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 151194 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 158018 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 171589 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 155261 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 167068 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 152768 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 166613 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 176542 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 150925 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 151020 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 154102 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 155156 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 167663 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 170978 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 154178 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 162105 microseconds (0 minutes, 0.16 seconds)
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 157731 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 147949 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 162488 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 150891 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 166585 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 169782 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# looping
# Benchmark: loaded "workload.txt"
# looping
# Benchmark: Workload workload.txt file took 166424 microseconds (0 minutes, 0.17 seconds)

# %%
results_df
# Out:
#     error_rate  num_pages  fanout  level_policy  time_taken
# 0         0.01        256       2  LAZY_LEVELED      181743
# 1         0.01        256       2       LEVELED      176230
# 2         0.01        256       2        TIERED      194845
# 3         0.01        256       5  LAZY_LEVELED      180092
# 4         0.01        256       5       LEVELED      164570
# 5         0.01        256       5        TIERED      217391
# 6         0.01        256      10  LAZY_LEVELED      213615
# 7         0.01        256      10       LEVELED      199795
# 8         0.01        256      10        TIERED      179534
# 9         0.01        512       2  LAZY_LEVELED      162339
# 10        0.01        512       2       LEVELED      178856
# 11        0.01        512       2        TIERED      184211
# 12        0.01        512       5  LAZY_LEVELED      178531
# 13        0.01        512       5       LEVELED      157629
# 14        0.01        512       5        TIERED      195337
# 15        0.01        512      10  LAZY_LEVELED      174042
# 16        0.01        512      10       LEVELED      196545
# 17        0.01        512      10        TIERED      194855
# 18        0.01       1024       2  LAZY_LEVELED      174550
# 19        0.01       1024       2       LEVELED      179084
# 20        0.01       1024       2        TIERED      178211
# 21        0.01       1024       5  LAZY_LEVELED      182806
# 22        0.01       1024       5       LEVELED      171453
# 23        0.01       1024       5        TIERED      162971
# 24        0.01       1024      10  LAZY_LEVELED      157294
# 25        0.01       1024      10       LEVELED      164786
# 26        0.01       1024      10        TIERED      149609
# 27        0.05        256       2  LAZY_LEVELED      161334
# 28        0.05        256       2       LEVELED      149669
# 29        0.05        256       2        TIERED      169260
# 30        0.05        256       5  LAZY_LEVELED      147755
# 31        0.05        256       5       LEVELED      151194
# 32        0.05        256       5        TIERED      158018
# 33        0.05        256      10  LAZY_LEVELED      171589
# 34        0.05        256      10       LEVELED      155261
# 35        0.05        256      10        TIERED      167068
# 36        0.05        512       2  LAZY_LEVELED      152768
# 37        0.05        512       2       LEVELED      166613
# 38        0.05        512       2        TIERED      176542
# 39        0.05        512       5  LAZY_LEVELED      150925
# 40        0.05        512       5       LEVELED      151020
# 41        0.05        512       5        TIERED      154102
# 42        0.05        512      10  LAZY_LEVELED      155156
# 43        0.05        512      10       LEVELED      167663
# 44        0.05        512      10        TIERED      170978
# 45        0.05       1024       2  LAZY_LEVELED      154178
# 46        0.05       1024       2       LEVELED      162105
# 47        0.05       1024       2        TIERED      157731
# 48        0.05       1024       5  LAZY_LEVELED      147949
# 49        0.05       1024       5       LEVELED      162488
# 50        0.05       1024       5        TIERED      150891
# 51        0.05       1024      10  LAZY_LEVELED      166585
# 52        0.05       1024      10       LEVELED      169782
# 53        0.05       1024      10        TIERED      166424

# %%
for error_rate in params['error_rate']:
    for level_policy in params['level_policy']:
        # Filter the data for the current error rate and level policy combination
        data = results_df[(results_df['error_rate'] == error_rate) & (results_df['level_policy'] == level_policy)]

# %%
# Create a heatmap of time taken with varying num_pages and fanout values
pivot_table = data.pivot_table(values='time_taken', index='num_pages', columns='fanout')
ax = sns.heatmap(pivot_table, annot=True, fmt='.2f', cmap='coolwarm')

# Set plot title and labels
ax.set_title(f'Error Rate: {error_rate}, Level Policy: {level_policy}')
ax.set_xlabel('Fanout')
ax.set_ylabel('Num Pages')

# Show the plot
plt.show()
