# %%
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import select
import time
import re
import os
import glob

def start_server(error_rate, num_pages, fanout, level_policy, port):
    cmd = f"./bin/server -e {error_rate} -n {num_pages} -f {fanout} -l {level_policy} -p {port}"
    server_process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    return server_process

def stop_server(server_process):
    server_process.terminate()
    #time.sleep(1)  # Wait 1 second to ensure the server has stopped

def delete_lsm_files():
    lsm_files = glob.glob('/tmp/lsm-*')
    for file in lsm_files:
        try:
            os.remove(file)
        except OSError:
            print(f"Error: Unable to delete file: {file}")

# %%
def wait_for_server_ready(server_process):
    start_time = time.time()
    timeout = 60  # Timeout in seconds

    while True:
        ready, _, _ = select.select([server_process.stdout], [], [], timeout)
        if ready:
            output_line = server_process.stdout.readline().decode()
            print(output_line, end="")
            if "New client connected" in output_line:
                break
        elif time.time() - start_time > timeout:
            raise TimeoutError("Server did not print 'New client connected' within the timeout period.")

def run_experiment(port, workload_path):
    client_cmd = f'./bin/client -p {port}'
    
    # Start the client process
    client_process = subprocess.Popen(client_cmd.split(), stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    
    # Wait for the server to print "New client connected"
    try:
        wait_for_server_ready(server_process)
    except TimeoutError as e:
        print(e)
        client_process.terminate()
        return None

    # Run the benchmark command
    benchmark_cmd = f'b {workload_path}\n'
    client_process.stdin.write(benchmark_cmd.encode())
    client_process.stdin.flush()

    time_taken = None
    while True:
        # Wait for output from the server process
        ready, _, _ = select.select([server_process.stdout], [], [], 60)  # timeout
        if ready:
            output_line = server_process.stdout.readline().decode()
            print(output_line, end="")
            match = re.search(r'(\d+) microseconds', output_line)
            if match:
                time_taken = int(match.group(1))
                break

    client_process.terminate()
    return time_taken

# %%
params = {
    'error_rate': [0.01, 0.05],
    'num_pages': [256, 512, 1024],
    'fanout': [2, 5, 10],
    'level_policy': ['LAZY_LEVELED', 'LEVELED', 'TIERED'],
    'port': 1249
}

results = []

delete_lsm_files()

for count, (error_rate, num_pages, fanout, level_policy) in enumerate(itertools.product(params['error_rate'], params['num_pages'], params['fanout'], params['level_policy'])):
    server_process = start_server(error_rate, num_pages, fanout, level_policy, params['port'] + count)
    time_taken = run_experiment(params['port'] + count, 'workload.txt')
    stop_server(server_process)

    result = {
        'error_rate': error_rate,
        'num_pages': num_pages,
        'fanout': fanout,
        'level_policy': level_policy,
        'time_taken': time_taken
    }
    results.append(result)

results_df = pd.DataFrame(results)
# Out:
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 196458 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1250
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 159467 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1251
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 210429 microseconds (0 minutes, 0.21 seconds)
#
# Server started, listening on port 1252
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 180991 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1253
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 186323 microseconds (0 minutes, 0.19 seconds)
#
# Server started, listening on port 1254
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 207501 microseconds (0 minutes, 0.21 seconds)
#
# Server started, listening on port 1255
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 204849 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1256
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 196231 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1257
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 187881 microseconds (0 minutes, 0.19 seconds)
#
# Server started, listening on port 1258
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 168740 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1259
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 165208 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1260
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 171015 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1261
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 152984 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1262
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 155198 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1263
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147205 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1264
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 152362 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1265
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 146452 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1266
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 170416 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1267
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 148111 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1268
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 146434 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1269
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 154262 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1270
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 202909 microseconds (0 minutes, 0.20 seconds)
#
# Server started, listening on port 1271
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 162093 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1272
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 166331 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1273
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 156263 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1274
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 187092 microseconds (0 minutes, 0.19 seconds)
#
# Server started, listening on port 1275
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 184734 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1276
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 164883 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1277
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 159368 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1278
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 157156 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1279
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 152767 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1280
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 150634 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1281
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147269 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1282
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 153107 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1283
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 164485 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1284
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147527 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1285
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147529 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1286
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 144569 microseconds (0 minutes, 0.14 seconds)
#
# Server started, listening on port 1287
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 156804 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1288
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 170631 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1289
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 156856 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1290
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 153055 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1291
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 157756 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1292
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 168374 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1293
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 142195 microseconds (0 minutes, 0.14 seconds)
#
# Server started, listening on port 1294
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 155160 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1295
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 150108 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1296
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 2
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 158081 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1297
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 157774 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1298
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147436 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1299
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 5
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 143122 microseconds (0 minutes, 0.14 seconds)
#
# Server started, listening on port 1300
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 156768 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1301
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 182996 microseconds (0 minutes, 0.18 seconds)
#
# Server started, listening on port 1302
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 156744 microseconds (0 minutes, 0.16 seconds)

# %%
results_df
# Out:
#     error_rate  num_pages  fanout  level_policy  time_taken
# 0         0.01        256       2  LAZY_LEVELED      196458
# 1         0.01        256       2       LEVELED      159467
# 2         0.01        256       2        TIERED      210429
# 3         0.01        256       5  LAZY_LEVELED      180991
# 4         0.01        256       5       LEVELED      186323
# 5         0.01        256       5        TIERED      207501
# 6         0.01        256      10  LAZY_LEVELED      204849
# 7         0.01        256      10       LEVELED      196231
# 8         0.01        256      10        TIERED      187881
# 9         0.01        512       2  LAZY_LEVELED      168740
# 10        0.01        512       2       LEVELED      165208
# 11        0.01        512       2        TIERED      171015
# 12        0.01        512       5  LAZY_LEVELED      152984
# 13        0.01        512       5       LEVELED      155198
# 14        0.01        512       5        TIERED      147205
# 15        0.01        512      10  LAZY_LEVELED      152362
# 16        0.01        512      10       LEVELED      146452
# 17        0.01        512      10        TIERED      170416
# 18        0.01       1024       2  LAZY_LEVELED      148111
# 19        0.01       1024       2       LEVELED      146434
# 20        0.01       1024       2        TIERED      154262
# 21        0.01       1024       5  LAZY_LEVELED      202909
# 22        0.01       1024       5       LEVELED      162093
# 23        0.01       1024       5        TIERED      166331
# 24        0.01       1024      10  LAZY_LEVELED      156263
# 25        0.01       1024      10       LEVELED      187092
# 26        0.01       1024      10        TIERED      184734
# 27        0.05        256       2  LAZY_LEVELED      164883
# 28        0.05        256       2       LEVELED      159368
# 29        0.05        256       2        TIERED      157156
# 30        0.05        256       5  LAZY_LEVELED      152767
# 31        0.05        256       5       LEVELED      150634
# 32        0.05        256       5        TIERED      147269
# 33        0.05        256      10  LAZY_LEVELED      153107
# 34        0.05        256      10       LEVELED      164485
# 35        0.05        256      10        TIERED      147527
# 36        0.05        512       2  LAZY_LEVELED      147529
# 37        0.05        512       2       LEVELED      144569
# 38        0.05        512       2        TIERED      156804
# 39        0.05        512       5  LAZY_LEVELED      170631
# 40        0.05        512       5       LEVELED      156856
# 41        0.05        512       5        TIERED      153055
# 42        0.05        512      10  LAZY_LEVELED      157756
# 43        0.05        512      10       LEVELED      168374
# 44        0.05        512      10        TIERED      142195
# 45        0.05       1024       2  LAZY_LEVELED      155160
# 46        0.05       1024       2       LEVELED      150108
# 47        0.05       1024       2        TIERED      158081
# 48        0.05       1024       5  LAZY_LEVELED      157774
# 49        0.05       1024       5       LEVELED      147436
# 50        0.05       1024       5        TIERED      143122
# 51        0.05       1024      10  LAZY_LEVELED      156768
# 52        0.05       1024      10       LEVELED      182996
# 53        0.05       1024      10        TIERED      156744

# %%
for error_rate in params['error_rate']:
    for level_policy in params['level_policy']:
        # Filter the data for the current error rate and level policy combination
        data = results_df[(results_df['error_rate'] == error_rate) & (results_df['level_policy'] == level_policy)]

# %%
# Create a heatmap of time taken with varying num_pages and fanout values
pivot_table = data.pivot_table(values='time_taken', index='num_pages', columns='fanout')
ax = sns.heatmap(pivot_table, annot=True, fmt='.2f', cmap='coolwarm')

# Set plot title and labels
ax.set_title(f'Error Rate: {error_rate}, Level Policy: {level_policy}')
ax.set_xlabel('Fanout')
ax.set_ylabel('Num Pages')

# Show the plot
plt.show()

# %%
params = {
    'error_rate': [0.01],
    'num_pages': [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024],
    'fanout': [10],
    'level_policy': ['LAZY_LEVELED', 'LEVELED', 'TIERED'],
    'port': 1234
}

results = []

delete_lsm_files()

for count, (error_rate, num_pages, fanout, level_policy) in enumerate(itertools.product(params['error_rate'], params['num_pages'], params['fanout'], params['level_policy'])):
    server_process = start_server(error_rate, num_pages, fanout, level_policy, params['port'] + count)
    time_taken = run_experiment(params['port'] + count, 'workload.txt')
    stop_server(server_process)

    result = {
        'error_rate': error_rate,
        'num_pages': num_pages,
        'fanout': fanout,
        'level_policy': level_policy,
        'time_taken': time_taken
    }
    results.append(result)

results_df = pd.DataFrame(results)
# Out:
# Server started, listening on port 1234
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 4635585 microseconds (0 minutes, 4.64 seconds)
#
# Server started, listening on port 1235
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 5067278 microseconds (0 minutes, 5.07 seconds)
#
# Server started, listening on port 1236
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 2178029 microseconds (0 minutes, 2.18 seconds)
#
# Server started, listening on port 1237
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 4096
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 3851630 microseconds (0 minutes, 3.85 seconds)
#
# Server started, listening on port 1238
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 4096
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 3891664 microseconds (0 minutes, 3.89 seconds)
#
# Server started, listening on port 1239
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 4096
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 2573046 microseconds (0 minutes, 2.57 seconds)
#
# Server started, listening on port 1240
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 2242156 microseconds (0 minutes, 2.24 seconds)
#
# Server started, listening on port 1241
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 2234665 microseconds (0 minutes, 2.23 seconds)
#
# Server started, listening on port 1242
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 1703187 microseconds (0 minutes, 1.70 seconds)
#
# Server started, listening on port 1243
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 528944 microseconds (0 minutes, 0.53 seconds)
#
# Server started, listening on port 1244
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 518652 microseconds (0 minutes, 0.52 seconds)
#
# Server started, listening on port 1245
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 246283 microseconds (0 minutes, 0.25 seconds)
#
# Server started, listening on port 1246
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 32768
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 222527 microseconds (0 minutes, 0.22 seconds)
#
# Server started, listening on port 1247
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 32768
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 221947 microseconds (0 minutes, 0.22 seconds)
#
# Server started, listening on port 1248
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 32768
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 214846 microseconds (0 minutes, 0.21 seconds)
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 65536
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 145383 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1250
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 65536
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 158529 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1251
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 65536
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 147364 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1252
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 131072
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 154518 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1253
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 131072
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 152588 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1254
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 131072
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 142585 microseconds (0 minutes, 0.14 seconds)
#
# Server started, listening on port 1255
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 262144
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 154668 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1256
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 262144
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 149307 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1257
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 262144
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 153734 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1258
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 170826 microseconds (0 minutes, 0.17 seconds)
#
# Server started, listening on port 1259
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 153205 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1260
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 153535 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1261
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 145587 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1262
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 146973 microseconds (0 minutes, 0.15 seconds)
#
# Server started, listening on port 1263
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 141677 microseconds (0 minutes, 0.14 seconds)
#
# Server started, listening on port 1264
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 163622 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1265
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 159603 microseconds (0 minutes, 0.16 seconds)
#
# Server started, listening on port 1266
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: loaded "workload.txt"
# Benchmark: Workload workload.txt file took 148884 microseconds (0 minutes, 0.15 seconds)

# %%
results_df
# Out:
#     error_rate  num_pages  fanout  level_policy  time_taken
# 0         0.01          1      10  LAZY_LEVELED     4635585
# 1         0.01          1      10       LEVELED     5067278
# 2         0.01          1      10        TIERED     2178029
# 3         0.01          2      10  LAZY_LEVELED     3851630
# 4         0.01          2      10       LEVELED     3891664
# 5         0.01          2      10        TIERED     2573046
# 6         0.01          4      10  LAZY_LEVELED     2242156
# 7         0.01          4      10       LEVELED     2234665
# 8         0.01          4      10        TIERED     1703187
# 9         0.01          8      10  LAZY_LEVELED      528944
# 10        0.01          8      10       LEVELED      518652
# 11        0.01          8      10        TIERED      246283
# 12        0.01         16      10  LAZY_LEVELED      222527
# 13        0.01         16      10       LEVELED      221947
# 14        0.01         16      10        TIERED      214846
# 15        0.01         32      10  LAZY_LEVELED      145383
# 16        0.01         32      10       LEVELED      158529
# 17        0.01         32      10        TIERED      147364
# 18        0.01         64      10  LAZY_LEVELED      154518
# 19        0.01         64      10       LEVELED      152588
# 20        0.01         64      10        TIERED      142585
# 21        0.01        128      10  LAZY_LEVELED      154668
# 22        0.01        128      10       LEVELED      149307
# 23        0.01        128      10        TIERED      153734
# 24        0.01        256      10  LAZY_LEVELED      170826
# 25        0.01        256      10       LEVELED      153205
# 26        0.01        256      10        TIERED      153535
# 27        0.01        512      10  LAZY_LEVELED      145587
# 28        0.01        512      10       LEVELED      146973
# 29        0.01        512      10        TIERED      141677
# 30        0.01       1024      10  LAZY_LEVELED      163622
# 31        0.01       1024      10       LEVELED      159603
# 32        0.01       1024      10        TIERED      148884

# %%
sns.set(style="darkgrid")
line_plot = sns.lineplot(data=results_df, x="num_pages", y="time_taken", hue="level_policy", style="level_policy", markers=True)

plt.xlabel("Number of Pages of Memory")
plt.ylabel("Time Taken")
plt.legend(title="Level Policy")
plt.yscale("log")  # Set y-axis to logarithmic scale - barely does anything
plt.show()

# %%
# Filter the DataFrame to keep only rows where num_pages >= 16
filtered_results_df = results_df[results_df['num_pages'] >= 16]

sns.set(style="darkgrid")
line_plot = sns.lineplot(data=filtered_results_df, x="num_pages", y="time_taken", hue="level_policy", style="level_policy", markers=True)

plt.xlabel("Number of Pages of Memory")
plt.ylabel("Time Taken")
plt.legend(title="Level Policy")
plt.show()
