# %%
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import select
import time
import re
import os
import sys
import glob

# Number of experimental runs to average together
num_experimental_runs = 10

port_inc = 0

def start_server(error_rate, num_pages, fanout, level_policy, port):
    global port_inc
    while True:
        cmd = f"./bin/server -e {error_rate} -n {num_pages} -f {fanout} -l {level_policy} -p {port}"
        server_process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        print(f"Starting the server on port {port}")

        # Read only the first line of stderr
        error_line = server_process.stderr.readline().decode()
        print(error_line, end="")
        sys.stdout.flush()

        if "Error binding server socket" in error_line:
            server_process.terminate()
            port += 1
            port_inc += 1
        else:
            return server_process



def stop_server(server_process):
    server_process.terminate()
    #time.sleep(1)  # Wait 1 second to ensure the server has stopped

def delete_lsm_files():
    lsm_files = glob.glob('/tmp/lsm-*')
    for file in lsm_files:
        try:
            os.remove(file)
        except OSError:
            print(f"Error: Unable to delete file: {file}")

# %%
# def wait_for_server_ready(server_process):
#     start_time = time.time()
#     timeout = 60  # Timeout in seconds

#     while True:
#         ready, _, _ = select.select([server_process.stdout], [], [], timeout)
#         if ready:
#             output_line = server_process.stdout.readline().decode()
#             print(output_line, end="")
#             if "New client connected" in output_line:
#                 break
#         elif time.time() - start_time > timeout:
#             raise TimeoutError("Server did not print 'New client connected' within the timeout period.")

def wait_for_server_ready(server_process):
    start_time = time.time()
    timeout = 600  # Timeout in seconds

    for output_line in iter(server_process.stdout.readline, b''):
        output_line = output_line.decode()
        #print("OUTPUT LINE: [" + output_line + "]")
        print(output_line, end="")
        sys.stdout.flush()
        if "New client connected" in output_line:
            break
        elif time.time() - start_time > timeout:
            raise TimeoutError("Server did not print 'New client connected' within the timeout period.")


def run_experiment(port, workload_path):
    client_cmd = f'./bin/client -p {port}'
    
    # Start the client process
    client_process = subprocess.Popen(client_cmd.split(), stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    
    # Wait for the server to print "New client connected"
    try:
        wait_for_server_ready(server_process)
    except TimeoutError as e:
        print(e)
        client_process.terminate()
        return None

    # Run the benchmark command
    benchmark_cmd = f'b {workload_path}\n'
    client_process.stdin.write(benchmark_cmd.encode())
    client_process.stdin.flush()

    time_taken = None
    while True:
        # Wait for output from the server process
        ready, _, _ = select.select([server_process.stdout], [], [], 60)  # timeout
        if ready:
            output_line = server_process.stdout.readline().decode()
            match = re.search(r'(\d+) microseconds', output_line)
            if match:
                time_taken = int(match.group(1))
                print(output_line, end="")
                sys.stdout.flush()
                break

    client_process.terminate()
    return time_taken

# %%
params = {
    'error_rate': [0.01, 0.05],
    'num_pages': [256, 512, 1024],
    'fanout': [2, 5, 10],
    'level_policy': ['LAZY_LEVELED', 'LEVELED', 'TIERED'],
    'port': 1249
}

results = []

delete_lsm_files()

for count, (error_rate, num_pages, fanout, level_policy) in enumerate(itertools.product(params['error_rate'], params['num_pages'], params['fanout'], params['level_policy'])):
    for run in range(num_experimental_runs):
        server_process = start_server(error_rate, num_pages, fanout, level_policy, params['port'] + port_inc)
        time_taken = run_experiment(params['port'] + port_inc, 'workload.txt')
        port_inc = port_inc + 1
        stop_server(server_process)

        result = {
            'error_rate': error_rate,
            'num_pages': num_pages,
            'fanout': fanout,
            'level_policy': level_policy,
            'time_taken': time_taken,
            'run': run
        }
        results.append(result)

results_df = pd.DataFrame(results)
# Out:
# Starting the server on port 1249
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1249
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 524288
#   LSM-tree fanout: 2
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took
# LSMTree parameters:
#   Bloom filter error rate: 0.05
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 177399 microseconds (0 minutes, 0.18 seconds)

# %%
results_df
# Out:
#      error_rate  num_pages  fanout  level_policy  time_taken  run
# 0          0.01        256       2  LAZY_LEVELED      217253    0
# 1          0.01        256       2  LAZY_LEVELED      190719    1
# 2          0.01        256       2  LAZY_LEVELED      179516    2
# 3          0.01        256       2  LAZY_LEVELED      172612    3
# 4          0.01        256       2  LAZY_LEVELED      202961    4
# ..          ...        ...     ...           ...         ...  ...
# 535        0.05       1024      10        TIERED      171602    5
# 536        0.05       1024      10        TIERED      177487    6
# 537        0.05       1024      10        TIERED      168642    7
# 538        0.05       1024      10        TIERED      170205    8
# 539        0.05       1024      10        TIERED      177399    9
#
# [540 rows x 6 columns]

# %%
for error_rate in params['error_rate']:
    for level_policy in params['level_policy']:
        # Filter the data for the current error rate and level policy combination
        data = results_df[(results_df['error_rate'] == error_rate) & (results_df['level_policy'] == level_policy)]

# %%
# Create a heatmap of time taken with varying num_pages and fanout values
pivot_table = data.pivot_table(values='time_taken', index='num_pages', columns='fanout')
plt.figure(figsize=(16, 8))

ax = sns.heatmap(pivot_table, annot=True, fmt='.2f', cmap='coolwarm')

# Set plot title and labels
ax.set_title(f'Error Rate: {error_rate}, Level Policy: {level_policy}')
ax.set_xlabel('Fanout')
ax.set_ylabel('Num Pages')

# Show the plot
plt.show()

# %%
params = {
    'error_rate': [0.01],
    'num_pages': [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024],
    'fanout': [10],
    'level_policy': ['LAZY_LEVELED', 'LEVELED', 'TIERED'],
    'port': 1234
}

results = []

delete_lsm_files()

for count, (error_rate, num_pages, fanout, level_policy) in enumerate(itertools.product(params['error_rate'], params['num_pages'], params['fanout'], params['level_policy'])):
    for run in range(num_experimental_runs):
        server_process = start_server(error_rate, num_pages, fanout, level_policy, params['port'] + port_inc)
        time_taken = run_experiment(params['port'] + port_inc, 'workload.txt')
        port_inc = port_inc + 1
        stop_server(server_process)

        result = {
            'error_rate': error_rate,
            'num_pages': num_pages,
            'fanout': fanout,
            'level_policy': level_policy,
            'time_taken': time_taken,
            'run': run
        }
        results.append(result)

results_df = pd.DataFrame(results)
# Out:
# Starting the server on port 1778
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1778
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4676375 microseconds (0 minutes, 4.68 seconds)
# Starting the server on port 1779
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1779
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4667198 microseconds (0 minutes, 4.67 seconds)
# Starting the server on port 1780
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1780
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4629020 microseconds (0 minutes, 4.63 seconds)
# Starting the server on port 1781
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1781
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4637680 microseconds (0 minutes, 4.64 seconds)
# Starting the server on port 1782
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1782
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4635810 microseconds (0 minutes, 4.64 seconds)
# Starting the server on port 1783
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1783
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4615899 microseconds (0 minutes, 4.62 seconds)
# Starting the server on port 1784
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1784
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4625793 microseconds (0 minutes, 4.63 seconds)
# Starting the server on port 1785
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1785
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4621608 microseconds (0 minutes, 4.62 seconds)
# Starting the server on port 1786
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1786
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4645588 microseconds (0 minutes, 4.65 seconds)
# Starting the server on port 1787
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1787
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2048
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 4619630 microseconds (0 minutes, 4.62 seconds)
# Starting the server on port 1788
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 2272971 microseconds (0 minutes, 2.27 seconds)
# Starting the server on port 1857
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1857
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 2258923 microseconds (0 minutes, 2.26 seconds)
# Starting the server on port 1858
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1858
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1706454 microseconds (0 minutes, 1.71 seconds)
# Starting the server on port 1859
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1859
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1728192 microseconds (0 minutes, 1.73 seconds)
# Starting the server on port 1860
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1860
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1721793 microseconds (0 minutes, 1.72 seconds)
# Starting the server on port 1861
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1861
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1747932 microseconds (0 minutes, 1.75 seconds)
# Starting the server on port 1862
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1862
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1720788 microseconds (0 minutes, 1.72 seconds)
# Starting the server on port 1863
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1863
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1703140 microseconds (0 minutes, 1.70 seconds)
# Starting the server on port 1864
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1864
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1743875 microseconds (0 minutes, 1.74 seconds)
# Starting the server on port 1865
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1865
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1729553 microseconds (0 minutes, 1.73 seconds)
# Starting the server on port 1866
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1866
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1733153 microseconds (0 minutes, 1.73 seconds)
# Starting the server on port 1867
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1867
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 8192
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 1738902 microseconds (0 minutes, 1.74 seconds)
# Starting the server on port 1868
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1868
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 541107 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1869
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1869
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 536241 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1870
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1870
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 535129 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1871
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1871
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 533361 microseconds (0 minutes, 0.53 seconds)
# Starting the server on port 1872
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1872
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 634337 microseconds (0 minutes, 0.63 seconds)
# Starting the server on port 1873
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
# Server started, listening on port 1873
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 541967 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1874
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1874
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 529830 microseconds (0 minutes, 0.53 seconds)
# Starting the server on port 1875
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1875
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 538333 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1876
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1876
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 547092 microseconds (0 minutes, 0.55 seconds)
# Starting the server on port 1877
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1877
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 558376 microseconds (0 minutes, 0.56 seconds)
# Starting the server on port 1878
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1878
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 538755 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1879
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1879
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 526381 microseconds (0 minutes, 0.53 seconds)
# Starting the server on port 1880
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1880
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 539068 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1881
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1881
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 533036 microseconds (0 minutes, 0.53 seconds)
# Starting the server on port 1882
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1882
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 540357 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1883
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1883
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 540028 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1884
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1884
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 546434 microseconds (0 minutes, 0.55 seconds)
# Starting the server on port 1885
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1885
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 538505 microseconds (0 minutes, 0.54 seconds)
# Starting the server on port 1886
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1886
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 534701 microseconds (0 minutes, 0.53 seconds)
# Starting the server on port 1887
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1887
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 524912 microseconds (0 minutes, 0.52 seconds)
# Starting the server on port 1888
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 1888
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 16384
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# ...
#
# Server started, listening on port 2071
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 172403 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2072
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2072
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 173401 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2073
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2073
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 168658 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2074
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2074
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 167866 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2075
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2075
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 190224 microseconds (0 minutes, 0.19 seconds)
# Starting the server on port 2076
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2076
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 187227 microseconds (0 minutes, 0.19 seconds)
# Starting the server on port 2077
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2077
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 1048576
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 167354 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2078
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2078
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 175568 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2079
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2079
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 175284 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2080
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2080
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 182403 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2081
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2081
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 167460 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2082
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
# Server started, listening on port 2082
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 175070 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2083
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2083
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 176421 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2084
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2084
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 177256 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2085
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2085
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 186722 microseconds (0 minutes, 0.19 seconds)
# Starting the server on port 2086
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2086
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 175892 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2087
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2087
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LAZY_LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 170549 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2088
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2088
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 189790 microseconds (0 minutes, 0.19 seconds)
# Starting the server on port 2089
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2089
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 182474 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2090
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2090
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 175778 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2091
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2091
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 166499 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2092
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2092
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 176684 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2093
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2093
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 173920 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2094
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2094
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 178702 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2095
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2095
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 182802 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2096
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2096
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 173812 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2097
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2097
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: LEVELED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 169830 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2098
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2098
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 181235 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2099
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2099
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 179446 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2100
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2100
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 176524 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2101
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
# Server started, listening on port 2101
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 181243 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2102
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2102
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 172760 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2103
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2103
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 179885 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2104
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2104
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 160793 microseconds (0 minutes, 0.16 seconds)
# Starting the server on port 2105
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2105
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 177312 microseconds (0 minutes, 0.18 seconds)
# Starting the server on port 2106
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2106
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 168192 microseconds (0 minutes, 0.17 seconds)
# Starting the server on port 2107
# No file /tmp/lsm-tree.json found or unable to open it. Creating fresh database.
#
# Server started, listening on port 2107
# LSMTree parameters:
#   Bloom filter error rate: 0.01
#   Number of buffer pages: 2097152
#   LSM-tree fanout: 10
#   Level policy: TIERED
#
# LSM Tree ready and waiting for input
# New client connected
# Benchmark: Workload workload.txt file took 187523 microseconds (0 minutes, 0.19 seconds)

# %%
results_df
# Out:
#      error_rate  num_pages  fanout  level_policy  time_taken  run
# 0          0.01          1      10  LAZY_LEVELED     4676375    0
# 1          0.01          1      10  LAZY_LEVELED     4667198    1
# 2          0.01          1      10  LAZY_LEVELED     4629020    2
# 3          0.01          1      10  LAZY_LEVELED     4637680    3
# 4          0.01          1      10  LAZY_LEVELED     4635810    4
# ..          ...        ...     ...           ...         ...  ...
# 325        0.01       1024      10        TIERED      179885    5
# 326        0.01       1024      10        TIERED      160793    6
# 327        0.01       1024      10        TIERED      177312    7
# 328        0.01       1024      10        TIERED      168192    8
# 329        0.01       1024      10        TIERED      187523    9
#
# [330 rows x 6 columns]

# %%
# This plot is too dominated by the page sizes less than 32
sns.set(style="darkgrid")
plt.figure(figsize=(16, 8))

grouped_df = results_df.groupby(["error_rate", "num_pages", "fanout", "level_policy"]).agg({"time_taken": "mean"}).reset_index()

line_plot = sns.lineplot(data=grouped_df, x="num_pages", y="time_taken", hue="level_policy", style="level_policy", markers=True)

plt.xlabel("Number of Pages of Memory")
plt.ylabel("Time Taken")
plt.legend(title="Level Policy")
plt.yscale("log")  # Set y-axis to logarithmic scale - barely does anything
plt.show()

# %%
# Filter the DataFrame to keep only rows where num_pages >= 32 (32 * 512 bytes per page so 16K buffer)
filtered_results_df = grouped_df[grouped_df['num_pages'] >= 32]

sns.set(style="darkgrid")
plt.figure(figsize=(16, 8))

line_plot = sns.lineplot(data=filtered_results_df, x="num_pages", y="time_taken", hue="level_policy", style="level_policy", markers=True)

plt.xlabel("Number of Pages of Memory")
plt.ylabel("Time Taken")
plt.legend(title="Level Policy")
plt.show()
